# %% [markdown]
# # Project 2：NASA Data Acquisation, Visualization, and Analysis

# %%
# The code makes sure that once there is change in the 'src/' folder, the 
# change will be automatically reloaded in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %aimport src

# %% [markdown]
# ### Task 1: Understanding the NASA API and Data Collection
#
# - Register for a NASA API key and understand the different types of data that the API provides.
# - Run the Python script below to fetch data about **Near Earth Objects (NEOs)** from the NASA API for a years data.
# - Extract and understand the different pieces of data provided for each NEO.

# %%
import requests
import time
from datetime import datetime, timedelta
from getpass import getpass
"""
# Set your NASA API KEY, this step asks you to enter your API KEY.
# (The input box may be float in the top on your editor.)
api_key = getpass()"""
# Out:
# '\n# Set your NASA API KEY, this step asks you to enter your API KEY.\n# (The input box may be float in the top on your editor.)\napi_key = getpass()'

# %%
"""
# Set the start and end dates for the data you want to fetch

start_date = datetime.strptime('2022-07-21', '%Y-%m-%d')
num_days = 165 
end_date = start_date + timedelta(days=num_days)  # 1 year later
# change above to full year!
# Initialize a list to store the data
data = []

# Fetch data from the NASA API 7 days at a time
# The introduction of the API is on https://api.nasa.gov, under "Browse APIs" -> "Asteroids NeoWs"
# You can look into the example query in the link below to see what the data look like:
# https://api.nasa.gov/neo/rest/v1/feed?start_date=2015-09-07&end_date=2015-09-08&api_key=DEMO_KEY
current_date = start_date
while current_date < end_date:
    next_date = min(current_date + timedelta(days=7), end_date)
    print("Current date: ", current_date)
    print("Next date: ", next_date)
    response = requests.get(f'https://api.nasa.gov/neo/rest/v1/feed?start_date={current_date.strftime("%Y-%m-%d")}&end_date={next_date.strftime("%Y-%m-%d")}&api_key={api_key}')
    data.append(response.json())
    current_date = next_date
    time.sleep(1)  # To avoid hitting the rate limit

# Now 'data' contains the NEO data for the 1-year period
print(data)"""
# Out:
# '\n# Set the start and end dates for the data you want to fetch\n\nstart_date = datetime.strptime(\'2022-07-21\', \'%Y-%m-%d\')\nnum_days = 165 \nend_date = start_date + timedelta(days=num_days)  # 1 year later\n# change above to full year!\n# Initialize a list to store the data\ndata = []\n\n# Fetch data from the NASA API 7 days at a time\n# The introduction of the API is on https://api.nasa.gov, under "Browse APIs" -> "Asteroids NeoWs"\n# You can look into the example query in the link below to see what the data look like:\n# https://api.nasa.gov/neo/rest/v1/feed?start_date=2015-09-07&end_date=2015-09-08&api_key=DEMO_KEY\ncurrent_date = start_date\nwhile current_date < end_date:\n    next_date = min(current_date + timedelta(days=7), end_date)\n    print("Current date: ", current_date)\n    print("Next date: ", next_date)\n    response = requests.get(f\'https://api.nasa.gov/neo/rest/v1/feed?start_date={current_date.strftime("%Y-%m-%d")}&end_date={next_date.strftime("%Y-%m-%d")}&api_key={api_key}\')\n    data.append(response.json())\n    current_date = next_date\n    time.sleep(1)  # To avoid hitting the rate limit\n\n# Now \'data\' contains the NEO data for the 1-year period\nprint(data)'

# %%
#Loading a years data from json file:
import json

f = open('Ayears_data.json')

# %%
data = json.load(f)

"""
# Save the data as a JSON file
with open('2022-07-2_to_200_days.json', 'w') as file:
    json.dump(data, file)

"""
# Out:
# "\n# Save the data as a JSON file\nwith open('2022-07-2_to_200_days.json', 'w') as file:\n    json.dump(data, file)\n\n"

# %%
# Check the date coverage of your data.
dates_contained_in_data = []
for d in data:
    dates_contained_in_data += list(d['near_earth_objects'].keys())

print(sorted(dates_contained_in_data))
# Out:
# ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08', '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-15', '2022-01-16', '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22', '2022-01-22', '2022-01-23', '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28', '2022-01-29', '2022-01-29', '2022-01-30', '2022-01-31', '2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04', '2022-02-05', '2022-02-05', '2022-02-06', '2022-02-07', '2022-02-08', '2022-02-09', '2022-02-10', '2022-02-11', '2022-02-12', '2022-02-12', '2022-02-13', '2022-02-14', '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18', '2022-02-19', '2022-02-19', '2022-02-20', '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26', '2022-02-26', '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04', '2022-03-05', '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12', '2022-03-12', '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-19', '2022-03-20', '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25', '2022-03-26', '2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01', '2022-04-02', '2022-04-02', '2022-04-03', '2022-04-04', '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-09', '2022-04-09', '2022-04-10', '2022-04-11', '2022-04-12', '2022-04-13', '2022-04-14', '2022-04-15', '2022-04-16', '2022-04-16', '2022-04-17', '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-23', '2022-04-24', '2022-04-25', '2022-04-26', '2022-04-27', '2022-04-28', '2022-04-29', '2022-04-30', '2022-04-30', '2022-05-01', '2022-05-02', '2022-05-03', '2022-05-04', '2022-05-05', '2022-05-06', '2022-05-07', '2022-05-07', '2022-05-08', '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12', '2022-05-13', '2022-05-14', '2022-05-14', '2022-05-15', '2022-05-16', '2022-05-17', '2022-05-18', '2022-05-19', '2022-05-20', '2022-05-21', '2022-05-21', '2022-05-22', '2022-05-23', '2022-05-24', '2022-05-25', '2022-05-26', '2022-05-27', '2022-05-28', '2022-05-28', '2022-05-29', '2022-05-30', '2022-05-31', '2022-06-01', '2022-06-02', '2022-06-03', '2022-06-04', '2022-06-04', '2022-06-05', '2022-06-06', '2022-06-07', '2022-06-08', '2022-06-09', '2022-06-10', '2022-06-11', '2022-06-11', '2022-06-12', '2022-06-13', '2022-06-14', '2022-06-15', '2022-06-16', '2022-06-17', '2022-06-18', '2022-06-18', '2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22', '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-25', '2022-06-26', '2022-06-27', '2022-06-28', '2022-06-29', '2022-06-30', '2022-07-01', '2022-07-02', '2022-07-02', '2022-07-03', '2022-07-04', '2022-07-05', '2022-07-06', '2022-07-07', '2022-07-08', '2022-07-09', '2022-07-09', '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13', '2022-07-14', '2022-07-15', '2022-07-16', '2022-07-16', '2022-07-17', '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21', '2022-07-22', '2022-07-23', '2022-07-24', '2022-07-25', '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-28', '2022-07-29', '2022-07-30', '2022-07-31', '2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04', '2022-08-04', '2022-08-05', '2022-08-06', '2022-08-07', '2022-08-08', '2022-08-09', '2022-08-10', '2022-08-11', '2022-08-11', '2022-08-12', '2022-08-13', '2022-08-14', '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18', '2022-08-18', '2022-08-19', '2022-08-20', '2022-08-21', '2022-08-22', '2022-08-23', '2022-08-24', '2022-08-25', '2022-08-25', '2022-08-26', '2022-08-27', '2022-08-28', '2022-08-29', '2022-08-30', '2022-08-31', '2022-09-01', '2022-09-01', '2022-09-02', '2022-09-03', '2022-09-04', '2022-09-05', '2022-09-06', '2022-09-07', '2022-09-08', '2022-09- ...

# %%
from src.utils import get_a_random_chunk_property
# Out:
# /Users/bruger/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
get_a_random_chunk_property(data)
# Out:
# date: 2022-11-23
# NEO name: (2022 WT27)
# id: 54354668

# %% [markdown]
# For the remaining tasks, you have to organize the data as pd.DataFrame so as to suit the specific need in each task. This part may require a considerably amount of efforts, which is normal in data science and analytics works.

# %% [markdown]
# ### Task 2: Data Analysis
#
# - Calculate the average size of the NEOs for each day.
# - Determine the proportion of NEOs that are potentially hazardous.
# - Find the NEO with the closest approach distance for each day.
# - Use statistical methods to analyze the data. For example, calculate the mean, median, mode, and standard deviation of the NEO sizes. Determine if the size of a NEO is correlated with whether it is potentially hazardous.

# %%
#Printing the data as json type:

#print(json.dumps(data, indent=4))  # indent=4 for pretty printing

# %%
## Data was as list and here we convert the data list into a dictionary:

data_dict = {}
for item in data:
    for date, neos in item['near_earth_objects'].items():
        if date not in data_dict:
            data_dict[date] = []
        data_dict[date].extend(neos)

# To check the date coverage of the data.
dates_contained_in_data = list(data_dict.keys())
def calculate_average_neo_size(data):
    # To create a dictionary to store the average size of NEOs for each day
    average_sizes = {}

    # Iterate over each day in the data
    for date, neos in data.items():
        neo_sizes = []

        # Iterate over each NEO for the current day and calculate its size
        for neo in neos:
            # Take the average of the estimated diameter min and max values for each NEO
            neo_size = (neo['estimated_diameter']['meters']['estimated_diameter_min'] + 
                        neo['estimated_diameter']['meters']['estimated_diameter_max']) / 2.0
            neo_sizes.append(neo_size)

        # Calculate the average size for the current day
        average_size = sum(neo_sizes) / len(neo_sizes)

        # Store the average size for the current day in the dictionary
        average_sizes[date] = average_size

    return average_sizes



average_sizes = calculate_average_neo_size(data_dict)
average_sizes = dict(sorted(average_sizes.items()))

print(json.dumps(average_sizes, indent=4))
# Out:
# {
#     "2022-01-01": 164.06950632386742,
#     "2022-01-02": 113.28381130161922,
#     "2022-01-03": 28.178929422507142,
#     "2022-01-04": 80.17934406791666,
#     "2022-01-05": 177.14896709935002,
#     "2022-01-06": 193.03476659451002,
#     "2022-01-07": 136.41669499568053,
#     "2022-01-08": 188.92085962588465,
#     "2022-01-09": 92.33174888921,
#     "2022-01-10": 129.81800097843333,
#     "2022-01-11": 91.59207763346748,
#     "2022-01-12": 102.13785365849286,
#     "2022-01-13": 136.8484155214075,
#     "2022-01-14": 273.76014224774707,
#     "2022-01-15": 94.58464650387778,
#     "2022-01-16": 111.76921471553334,
#     "2022-01-17": 252.19978835415202,
#     "2022-01-18": 206.4277140964094,
#     "2022-01-19": 101.74826853529001,
#     "2022-01-20": 113.04951510122729,
#     "2022-01-21": 202.15950938433684,
#     "2022-01-22": 134.2432870377,
#     "2022-01-23": 213.10405239637856,
#     "2022-01-24": 158.45032266666192,
#     "2022-01-25": 202.90064994384474,
#     "2022-01-26": 93.43305810566112,
#     "2022-01-27": 123.68635149364735,
#     "2022-01-28": 113.98971610996605,
#     "2022-01-29": 298.8924781469559,
#     "2022-01-30": 162.85954117933335,
#     "2022-01-31": 246.91612141438003,
#     "2022-02-01": 79.41068102615475,
#     "2022-02-02": 180.86922094350209,
#     "2022-02-03": 72.34058581597225,
#     "2022-02-04": 101.97378029004332,
#     "2022-02-05": 168.30793610475578,
#     "2022-02-06": 218.93410385032,
#     "2022-02-07": 151.01005330123215,
#     "2022-02-08": 114.43134601231445,
#     "2022-02-09": 240.53007791843248,
#     "2022-02-10": 113.82174302195715,
#     "2022-02-11": 85.35640153537084,
#     "2022-02-12": 143.71049419837192,
#     "2022-02-13": 82.10438463388078,
#     "2022-02-14": 87.10501773576054,
#     "2022-02-15": 188.00979134108678,
#     "2022-02-16": 182.53781297672384,
#     "2022-02-17": 104.80228224404165,
#     "2022-02-18": 196.9396557817684,
#     "2022-02-19": 301.25214643925204,
#     "2022-02-20": 308.1722423326473,
#     "2022-02-21": 111.74411903443077,
#     "2022-02-22": 135.71362201248,
#     "2022-02-23": 158.82522916820207,
#     "2022-02-24": 305.9939843912749,
#     "2022-02-25": 137.8715393110375,
#     "2022-02-26": 180.17629197460002,
#     "2022-02-27": 73.13849900431084,
#     "2022-02-28": 146.17457323699998,
#     "2022-03-01": 68.14232038608054,
#     "2022-03-02": 74.37635388997597,
#     "2022-03-03": 105.065076053555,
#     "2022-03-04": 217.97125347522393,
#     "2022-03-05": 109.3895387325068,
#     "2022-03-06": 94.21148588514602,
#     "2022-03-07": 118.21504458603913,
#     "2022-03-08": 122.10892916055909,
#     "2022-03-09": 103.06788184742497,
#     "2022-03-10": 193.98509290822244,
#     "2022-03-11": 138.4743365269731,
#     "2022-03-12": 208.74495636928845,
#     "2022-03-13": 119.42162693541665,
#     "2022-03-14": 92.6694550451295,
#     "2022-03-15": 269.4741070088433,
#     "2022-03-16": 358.1959732821286,
#     "2022-03-17": 59.34009541994063,
#     "2022-03-18": 49.94003514822144,
#     "2022-03-19": 130.60912088024688,
#     "2022-03-20": 66.31657787649375,
#     "2022-03-21": 151.89107729347106,
#     "2022-03-22": 116.11806097554336,
#     "2022-03-23": 129.3902718496525,
#     "2022-03-24": 128.61406960748928,
#     "2022-03-25": 98.49800035797496,
#     "2022-03-26": 114.2116092845854,
#     "2022-03-27": 340.39073225616926,
#     "2022-03-28": 285.46620966436336,
#     "2022-03-29": 111.3056813346682,
#     "2022-03-30": 152.15385497467602,
#     "2022-03-31": 95.95373474674001,
#     "2022-04-01": 85.79663481030772,
#     "2022-04-02": 78.91465856168666,
#     "2022-04-03": 191.08871192474666,
#     "2022-04-04": 60.212177487463144,
#     "2022-04-05": 126.38567628687498,
#     "2022-04-06": 100.16214136693215,
#     "2022-04-07": 101.10506800395588,
#     "2022-04-08": 146.76310200256114,
#     "2022-04-09": 163.79516639053253,
#     "2022-04-10": 102.4045059621815,
#     "2022-04-11": 125.24785967610553,
#     "2022-04-12": 224.89790909352004,
#     "2022-04-13": 109.3776691442275,
#     "2022-04-14": 140.83478097743847,
#     "2022-04-15": 62.718388048623076,
#     "2022-04-16": 63.12948669105938,
#     "2022-04-17": 81.16210065884687,
#     "2022-04-18": 132.987270705675,
#     "2022-04-19": 133.58938892253045,
#     "2022-04-20": 85.61609733838947,
#     "2022-04-21": 57.95054213392501,
#     "2022-04-22": 194.52241913089685,
#     "2022-04-23": 97.91421621088823,
#     "2022-04-24": 101.1370150910375,
#     "2022-04-25": 103.97552014385191,
#     "2022-04-26": 149.54155254142105,
#     "2022-04-27": 68.22209381601819,
#     "2022-04-28": 137.3948088817166,
#     "2022-04-29": 96.449936603505,
#     "2022-04-30": 236.80775313330403,
#     "2022-05-01": 110.3775773136741,
#     "2022-05-02": 138.83442460193916,
#     "2022-05-03": 148.61638494782494,
#     "2022-05-04": 237.4445183605667,
#     "2022-05-05": 81.25591083612333,
#     "2022-05-06": 144.92149014149285,
#     "2022-05-07": 160.27823727701664,
#     "2022-05-08": 153.34418057035938,
#     "2022-05-09": 131.57453642205311,
#     "2022-05-10": 139.32955961909704,
#     "2022-05-11": 142.36423258116105,
#     "2022-05-12": 136.73369648708925,
#     "2022-05-13": 243.41293997641787,
#     "2022-05-14": 149.29758084816004,
#     "2022-05-15": 134.0460331694861,
#     "2022-05-16": 115.03014717460754,
#     "2022-05-17": 253.05599809560556,
#     "2022-05-18": 62.91438097763076,
#     "2022-05-19": 86.63518704991749,
#     "2022-05-20": 82.3109460733725,
#     "2022-05-21": 60.92665782924998,
#     "2022-05-22": 163.94491522351004,
#     "2022-05-23": 121.6224991874719,
#     "2022-05-24": 154.3511712569143,
#     "2022-05-25": 55.10298909008056,
#     "2022-05-26": 65.97272417889167,
#     "2022-05-27": 192.49083564752405,
#     "2022-05-28": 208.85068261523233,
#     "2022-05-29": 129.99438178801154,
#     "2022-05-30": 107.22988467483127,
#     "2022-05-31": 125.93613704382857,
#     "2022-06-01": 163.4166756241727,
#     "2022-06-02": 52.07754198182666,
#     "2022-06-03": 114.29230911610787,
#     "2022-06-04": 69.86917022475384,
#     "2022-06-05": 77.48233744911154,
#     "2022-06-06": 258.6334169642632,
#     "2022-06-07": 112.4427837906375,
#     "2022-06-08": 90.33910883025834,
#     "2022-06-09": 198.02129260920276,
#     "2022-06-10": 195.1721786524824,
#     "2022-06-11": 311.94964955025915,
#     "2022-06-12": 69.01257534962335,
#     "2022-06-13": 328.36803694214444,
#     "2022-06-14": 329.3022929634857,
#     "2022-06-15": 151.89311471042,
#     "2022-06-16": 151.22570244286786,
#     "2022-06-17": 152.05498329989064,
#     "2022-06-18": 322.4498555311334,
#     "2022-06-19": 206.36924851915,
#     "2022-06-20": 270.7101599572,
#     "2022-06-21": 248.9806504953,
#     "2022-06-22": 174.40256997169286,
#     "2022-06-23": 377.5504668183499,
#     "2022-06-24": 181.48574296822497,
#     "2022-06-25": 195.16943109297858,
#     "2022-06-26": 156.72706459721564,
#     "2022-06-27": 128.61813481860574,
#     "2022-06-28": 136.3127660989889,
#     "2022-06-29": 258.5268751971322,
#     "2022-06-30": 176.74494129986257,
#     "2022-07-01": 210.86491426703466,
#     "2022-07-02": 215.2792336770358,
#     "2022-07-03": 235.03168583849117,
#     "2022-07-04": 143.922992579625,
#     "2022-07-05": 131.01051430413332,
#     "2022-07-06": 554.0470370345438,
#     "2022-07-07": 141.02625230745716,
#     "2022-07-08": 149.49172701982502,
#     "2022-07-09": 288.6030229082853,
#     "2022-07-10": 83.95006292504115,
#     "2022-07-11": 408.4885161923278,
#     "2022-07-12": 169.00356418566665,
#     "2022-07-13": 247.4789597592923,
#     "2022-07-14": 166.46025556640328,
#     "2022-07-15": 287.6132918850579,
#     "2022-07-16": 226.37895769246472,
#     "2022-07-17": 124.60970899871427,
#     "2022-07-18": 301.54756598470624,
#     "2022-07-19": 350.66879814961544,
#     "2022-07-20": 320.805556752253,
#     "2022-07-21": 150.91573550445625,
#     "2022-07-22": 222.26318417748533,
#     "2022-07-23": 603.6254693142423,
#     "2022-07-24": 154.37484401178747,
#     "2022-07-25": 283.1573940114459,
#     "2022-07-26": 178.92826857226004,
#     "2022-07-27": 343.39782673388464,
#     "2022-07-28": 206.4284840147577,
#     "2022-07-29": 136.66358179383545,
#     "2022-07-30": 131.925134723725,
#     "2022-07-31": 116.775631564415,
#     "2022-08-01": 53.63841428752499,
#     "2022-08-02": 86.64092681165415,
#     "2022-08-03": 135.78818262509284,
#     "2022-08-04": 117.90093960443699,
#     "2022-08-05": 131.03344951697943,
#     "2022-08-06": 171.88233198634617,
#     "2022-08-07": 209.35669970183568,
#     "2022-08-08": 137.76437814831252,
#     "2022-08-09": 197.3345863363786,
#     "2022-08-10": 145.96458707779166,
#     "2022-08-11": 119.51876641716667,
#     "2022-08-12": 148.58140252004168,
#     "2022-08-13": 162.80521161796747,
#     "2022-08-14": 108.25989795755623,
#     "2022-08-15": 235.03569608661365,
#     "2022-08-16": 180.5962599139822,
#     "2022-08-17": 139.98781550521,
#     "2022-08-18": 170.5325823122526,
#     "2022-08-19": 90.48832781278236,
#     "2022-08-20": 151.00901268646666,
#     "2022-08-21": 187.23306699261065,
#     "2022-08-22": 76.16039534253751,
#     "2022-08-23": 100.76433816665417,
#     "2022-08-24": 118.33967490118572,
#     "2022-08-25": 95.76066888114,
#     "2022-08-26": 81.94365223220385,
#     "2022-08-27": 108.278889942974,
#     "2022-08-28": 106.34113669438568,
#     "2022-08-29": 265.0770612593001,
#     "2022-08-30": 58.532106321069236,
#     "2022-08-31": 251.0482703995,
#     "2022-09-01": 216.04354748967887,
#     "2022-09-02": 107.5011601091619,
#     "2022-09-03": 141.9797955692167,
#     "2022-09-04": 128.70449567311366,
#     "2022-09-05": 80.8588980361875,
#     "2022-09-06": 99.44859495562143,
#     "2022-09-07": 127.71215858394524,
#     "2022-09-08": 136.51664004310908,
#     "2022-09-09": 194.17109270233883,
#     "2022-09-10": 175.4068900126789,
#     "2022-09-11": 187.59769790651575,
#     "2022-09-12": 95.44542115727577,
#     "2022-09-13": 117.03709414519997,
#     "2022-09-14": 159.8649447107604,
#     "2022-09-15": 166.7214766362262,
#     "2022-09-16": 104.90666856616971,
#     "2022-09-17": 107.01039603948,
#     "2022-09-18": 175.33510293177497,
#     "2022-09-19": 104.12928524959771,
#     "2022-09-20": 83.10516069671388,
#     "2022-09-21": 160.37360762885962,
#     "2022-09-22": 82.6206029755326,
#     "2022-09-23": 63.96193187075001,
#     "2022-09-24": 123.26722658729526,
#     "2022-09-25": 160.94165750051093,
#     "2022-09-26": 70.52600549671666,
#     "2022-09-27": 141.72782553440288,
#     "2022-09-28": 109.71355156001519,
#     "2022-09-29": 132.81493671501298,
#     "2022-09-30": 127.46240642930665,
#     "2022-10-01": 85.90963834045172,
#     "2022-10-02": 120.42994555380004,
#     "2022-10-03": 88.85269133800332,
#     "2022-10-04": 197.1317833440925,
#     "2022-10-05": 184.48695731678083,
#     "2022-10-06": 149.70273757104138,
#     "2022-10-07": 223.75771210501998,
#     "2022-10-08": 225.23110143462964,
#     "2022-10-09": 65.6493956496475,
#     "2022-10-10": 123.87321736668845,
#     "2022-10-11": 132.274013908525,
#     "2022-10-12": 338.8970688801999,
#     "2022-10-13": 107.75387334491766,
#     "2022-10-14": 99.58166384032728,
#     "2022-10-15": 135.55908525229805,
#     "2022-10-16": 151.12333957051874,
#     "2022-10-17": 207.82844169680712,
#     "2022-10-18": 175.336691019805,
#     "2022-10-19": 111.9260228332297,
#     "2022-10-20": 89.65634663201809,
#     "2022-10-21": 71.4426816556516,
#     "2022-10-22": 107.28493001947001,
#     "2022-10-23": 108.95979229106365,
#     "2022-10-24": 90.67039455583873,
#     "2022-10-25": 108.4612659794346,
#     "2022-10-26": 73.16988990064267,
#     "2022-10-27": 99.93205223515999,
#     "2022-10-28": 140.27288578026037,
#     "2022-10-29": 141.75427743255625,
#     "2022-10-30": 93.79025291315556,
#     "2022-10-31": 91.40765670225,
#     "2022-11-01": 134.81454532265386,
#     "2022-11-02": 245.0103381922454,
#     "2022-11-03": 137.2302068242174,
#     "2022-11-04": 91.78131814980684,
#     "2022-11-05": 93.2917290854975,
#     "2022-11-06": 137.96251966859836,
#     "2022-11-07": 82.6732378359281,
#     "2022-11-08": 78.29011220720166,
#     "2022-11-09": 112.09775760314999,
#     "2022-11-10": 185.42894912954452,
#     "2022-11-11": 71.0702363370143,
#     "2022-11-12": 277.76147306593094,
#     "2022-11-13": 140.67901196226137,
#     "2022-11-14": 104.79156187074412,
#     "2022-11-15": 76.36412220933235,
#     "2022-11-16": 116.96731860881843,
#     "2022-11-17": 259.4612115241642,
#     "2022-11-18": 110.62232958565895,
#     "2022-11-19": 67.62423084108126,
#     "2022-11-20": 274.65766562388836,
#     "2022-11-21": 224.8991722176999,
#     "2022-11-22": 97.261139012034,
#     "2022-11-23": 94.38840673578044,
#     "2022-11-24": 108.54243214558528,
#     "2022-11-25": 233.5008598460478,
#     "2022-11-26": 127.88316157809705,
#     "2022-11-27": 75.88894778613331,
#     "2022-11-28": 150.80393912746578,
#     "2022-11-29": 147.65189280044498,
#     "2022-11-30": 168.38931870945217,
#     "2022-12-01": 128.79557712906845,
#     "2022-12-02": 96.45226587359655,
#     "2022-12-03": 313.65961048494313,
#     "2022-12-04": 168.52839993656391,
#     "2022-12-05": 231.1590409755083,
#     "2022-12-06": 103.64378570835935,
#     "2022-12-07": 123.76501843264,
#     "2022-12-08": 104.89196772116176,
#     "2022-12-09": 123.72780142019829,
#     "2022-12-10": 101.97731330824686,
#     "2022-12-11": 360.8314882471577,
#     "2022-12-12": 283.45373316985996,
#     "2022-12-13": 74.272951417675,
#     "2022-12-14": 126.01543538842918,
#     "2022-12-15": 112.38431703947855,
#     "2022-12-16": 133.61791894383504,
#     "2022-12-17": 95.31459956561248,
#     "2022-12-18": 129.13470725446905,
#     "2022-12-19": 128.0662440887834,
#     "2022-12-20": 148.60453793591853,
#     "2022-12-21": 230.0674624776677,
#     "2022-12-22": 165.60563564293994,
#     "2022-12-23": 89.54331435361999,
#     "2022-12-24": 158.1236096408737,
#     "2022-12-25": 113.5459795034342,
#     "2022-12-26": 91.3703665228139,
#     "2022-12-27": 209.53651307812854,
#     "2022-12-28": 125.47272358945938,
#     "2022-12-29": 188.91664037021116,
#     "2022-12-30": 137.4821362554214,
#     "2022-12-31": 52.29138762849688,
#     "2023-01-01": 305.0945979447326,
#     "2023-01-02": 183.89869065350317
# }

# %%
# Write your code
import pandas as pd

# data is a list of dicts containing json response data
# DATA TYPE: <class 'list'>
# DATA0 TYPE: <class 'dict'>
# NEO TYPE: <class 'dict'>
# INDEX TYPE <class 'tuple'>
# temp_df is a pandas dataframe
# write down what data types are needed!

#print("Num of days used: ", num_days)
#print("Num of weeks used:", int(num_days/7))
for val in range(int(num_days/7)): # convert to num of weeks
    neo = data[val]['near_earth_objects']
    for neo_object in sorted(neo.items()):
        print("Date:", neo_object[0])
        temp_df = pd.json_normalize(neo, record_path=neo_object[0])
        # print(temp_df.head())
        # print(temp_df['absolute_magnitude_h'].describe())

        # hazardous asteroid calculations
        df_dangerous_false = len(temp_df[temp_df['is_potentially_hazardous_asteroid']==False])
        df_dangerous_true = len(temp_df[temp_df['is_potentially_hazardous_asteroid']==True])
        print(" Dangerous:", df_dangerous_true)
        print(" Non-dangeorus:", df_dangerous_false)
        print("     Proportion:", 100*df_dangerous_true/df_dangerous_false, "%")

        # yet to expand near miss data


# df = pd.DataFrame(data)
# df.describe()
# below just for reference
temp = {
    'links': {
        'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-01-08&end_date=2022-01-15&detailed=false&api_key=DEMO_KEY',
        'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2021-12-25&end_date=2022-01-01&detailed=false&api_key=DEMO_KEY',
        'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-01-01&end_date=2022-01-08&detailed=false&api_key=DEMO_KEY'
    },
    'element_count': 125,
    'near_earth_objects': {
        '2022-01-07': [{
            'links': {
                'self': 'http://api.nasa.gov/neo/rest/v1/neo/2216523?api_key=DEMO_KEY'
            },
            'id': '2216523',
            'neo_reference_id': '2216523',
            'name': '216523 (2001 HY7)',
            'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2216523',
            'absolute_magnitude_h': 20.7,
            'estimated_diameter': {
                'kilometers': {
                    'estimated_diameter_min': 0.1925550782,
                    'estimated_diameter_max': 0.4305662442
                },
                'meters': {
                    'estimated_diameter_min': 192.5550781879,
                    'estimated_diameter_max': 430.566244241
                },
                'miles': {
                    'estimated_diameter_min': 0.1196481415,
                    'estimated_diameter_max': 0.2675413778
                },
                'feet': {
                    'estimated_diameter_min': 631.7424027221,
                    'estimated_diameter_max': 1412.6189567557
                }
            },
            'is_potentially_hazardous_asteroid': True,
            'close_approach_data': [{
                'close_approach_date': '2022-01-07',
                'close_approach_date_full': '2022-Jan-07 06:54',
                'epoch_date_close_approach': 1641538440000,
                'relative_velocity': {
                    'kilometers_per_second': '13.0121884925',
                    'kilometers_per_hour': '46843.8785729622',
                    'miles_per_hour': '29106.9644388498'
                },
                'miss_distance': {
                    'astronomical': '0.3880911625',
                    'lunar': '150.9674622125',
                    'kilometers': '58057611.275823875',
                    'miles': '36075326.811664475'
                },
                'orbiting_body': 'Earth'
            }],
            'is_sentry_object': False
        }]
    }
}
# print("TEMP TYPE:", type(temp))

# new_df = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in df['near_earth_objects']],ignore_index=True)
# print(new_df)
# characteristics_df = 
# approach_df = 
# print()
# Out:
# Date: 2022-01-01
#  Dangerous: 1
#  Non-dangeorus: 19
#      Proportion: 5.2631578947368425 %
# Date: 2022-01-02
#  Dangerous: 0
#  Non-dangeorus: 13
#      Proportion: 0.0 %
# Date: 2022-01-03
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-01-04
#  Dangerous: 1
#  Non-dangeorus: 8
#      Proportion: 12.5 %
# Date: 2022-01-05
#  Dangerous: 1
#  Non-dangeorus: 11
#      Proportion: 9.090909090909092 %
# Date: 2022-01-06
#  Dangerous: 1
#  Non-dangeorus: 16
#      Proportion: 6.25 %
# Date: 2022-01-07
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-01-08
#  Dangerous: 1
#  Non-dangeorus: 8
#      Proportion: 12.5 %
# Date: 2022-01-08
#  Dangerous: 1
#  Non-dangeorus: 8
#      Proportion: 12.5 %
# Date: 2022-01-09
#  Dangerous: 0
#  Non-dangeorus: 14
#      Proportion: 0.0 %
# Date: 2022-01-10
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-01-11
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-01-12
#  Dangerous: 1
#  Non-dangeorus: 19
#      Proportion: 5.2631578947368425 %
# Date: 2022-01-13
#  Dangerous: 1
#  Non-dangeorus: 18
#      Proportion: 5.555555555555555 %
# Date: 2022-01-14
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-01-15
#  Dangerous: 2
#  Non-dangeorus: 16
#      Proportion: 12.5 %
# Date: 2022-01-15
#  Dangerous: 2
#  Non-dangeorus: 16
#      Proportion: 12.5 %
# Date: 2022-01-16
#  Dangerous: 1
#  Non-dangeorus: 15
#      Proportion: 6.666666666666667 %
# Date: 2022-01-17
#  Dangerous: 2
#  Non-dangeorus: 19
#      Proportion: 10.526315789473685 %
# Date: 2022-01-18
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-01-19
#  Dangerous: 1
#  Non-dangeorus: 8
#      Proportion: 12.5 %
# Date: 2022-01-20
#  Dangerous: 3
#  Non-dangeorus: 19
#      Proportion: 15.789473684210526 %
# Date: 2022-01-21
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-01-22
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-01-22
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-01-23
#  Dangerous: 2
#  Non-dangeorus: 18
#      Proportion: 11.11111111111111 %
# Date: 2022-01-24
#  Dangerous: 2
#  Non-dangeorus: 16
#      Proportion: 12.5 %
# Date: 2022-01-25
#  Dangerous: 3
#  Non-dangeorus: 14
#      Proportion: 21.428571428571427 %
# Date: 2022-01-26
#  Dangerous: 0
#  Non-dangeorus: 17
#      Proportion: 0.0 %
# Date: 2022-01-27
#  Dangerous: 2
#  Non-dangeorus: 13
#      Proportion: 15.384615384615385 %
# Date: 2022-01-28
#  Dangerous: 0
#  Non-dangeorus: 27
#      Proportion: 0.0 %
# Date: 2022-01-29
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-01-29
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-01-30
#  Dangerous: 2
#  Non-dangeorus: 15
#      Proportion: 13.333333333333334 %
# Date: 2022-01-31
#  Dangerous: 0
#  Non-dangeorus: 11
#      Proportion: 0.0 %
# Date: 2022-02-01
#  Dangerous: 0
#  Non-dangeorus: 21
#      Proportion: 0.0 %
# Date: 2022-02-02
#  Dangerous: 2
#  Non-dangeorus: 18
#      Proportion: 11.11111111111111 %
# Date: 2022-02-03
#  Dangerous: 0
#  Non-dangeorus: 25
#      Proportion: 0.0 %
# Date: 2022-02-04
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-02-05
#  Dangerous: 1
#  Non-dangeorus: 21
#      Proportion: 4.761904761904762 %
# Date: 2022-02-05
#  Dangerous: 1
#  Non-dangeorus: 21
#      Proportion: 4.761904761904762 %
# Date: 2022-02-06
#  Dangerous: 0
#  Non-dangeorus: 13
#      Proportion: 0.0 %
# Date: 2022-02-07
#  Dangerous: 1
#  Non-dangeorus: 12
#      Proportion: 8.333333333333334 %
# Date: 2022-02-08
#  Dangerous: 0
#  Non-dangeorus: 32
#      Proportion: 0.0 %
# Date: 2022-02-09
#  Dangerous: 2
#  Non-dangeorus: 15
#      Proportion: 13.333333333333334 %
# Date: 2022-02-10
#  Dangerous: 2
#  Non-dangeorus: 18
#      Proportion: 11.11111111111111 %
# Date: 2022-02-11
#  Dangerous: 0
#  Non-dangeorus: 11
#      Proportion: 0.0 %
# Date: 2022-02-12
#  Dangerous: 1
#  Non-dangeorus: 14
#      Proportion: 7.142857142857143 %
# Date: 2022-02-12
#  Dangerous: 1
#  Non-dangeorus: 14
#      Proportion: 7.142857142857143 %
# Date: 2022-02-13
#  Dangerous: 0
#  Non-dangeorus: 10
#      Proportion: 0.0 %
# Date: 2022-02-14
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-02-15
#  Dangerous: 2
#  Non-dangeorus: 14
#      Proportion: 14.285714285714286 %
# Date: 2022-02-16
#  Dangerous: 1
#  Non-dangeorus: 19
#      Proportion: 5.2631578947368425 %
# Date: 2022-02-17
#  Dangerous: 1
#  Non-dangeorus: 10
#      Proportion: 10.0 %
# Date: 2022-02-18
#  Dangerous: 2
#  Non-dangeorus: 16
#      Proportion: 12.5 %
# Date: 2022-02-19
#  Dangerous: 1
#  Non-dangeorus: 22
#      Proportion: 4.545454545454546 %
# Date: 2022-02-19
#  Dangerous: 1
#  Non-dangeorus: 22
#      Proportion: 4.545454545454546 %
# Date: 2022-02-20
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-02-21
#  Dangerous: 1
#  Non-dangeorus: 12
#      Proportion: 8.333333333333334 %
# Date: 2022-02-22
#  Dangerous: 1
#  Non-dangeorus: 17
#      Proportion: 5.882352941176471 %
# Date: 2022-02-23
#  Dangerous: 1
#  Non-dangeorus: 21
#      Proportion: 4.761904761904762 %
# Date: 2022-02-24
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-02-25
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-02-26
#  Dangerous: 0
#  Non-dangeorus: 21
#      Proportion: 0.0 %
# Date: 2022-02-26
#  Dangerous: 0
#  Non-dangeorus: 21
#      Proportion: 0.0 %
# Date: 2022-02-27
#  Dangerous: 1
#  Non-dangeorus: 20
#      Proportion: 5.0 %
# Date: 2022-02-28
#  Dangerous: 2
#  Non-dangeorus: 22
#      Proportion: 9.090909090909092 %
# Date: 2022-03-01
#  Dangerous: 1
#  Non-dangeorus: 15
#      Proportion: 6.666666666666667 %
# Date: 2022-03-02
#  Dangerous: 0
#  Non-dangeorus: 22
#      Proportion: 0.0 %
# Date: 2022-03-03
#  Dangerous: 0
#  Non-dangeorus: 16
#      Proportion: 0.0 %
# Date: 2022-03-04
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-03-05
#  Dangerous: 0
#  Non-dangeorus: 20
#      Proportion: 0.0 %
# Date: 2022-03-05
#  Dangerous: 0
#  Non-dangeorus: 20
#      Proportion: 0.0 %
# Date: 2022-03-06
#  Dangerous: 1
#  Non-dangeorus: 21
#      Proportion: 4.761904761904762 %
# Date: 2022-03-07
#  Dangerous: 0
#  Non-dangeorus: 22
#      Proportion: 0.0 %
# Date: 2022-03-08
#  Dangerous: 1
#  Non-dangeorus: 9
#      Proportion: 11.11111111111111 %
# Date: 2022-03-09
#  Dangerous: 0
#  Non-dangeorus: 16
#      Proportion: 0.0 %
# Date: 2022-03-10
#  Dangerous: 1
#  Non-dangeorus: 16
#      Proportion: 6.25 %
# Date: 2022-03-11
#  Dangerous: 2
#  Non-dangeorus: 10
#      Proportion: 20.0 %
# Date: 2022-03-12
#  Dangerous: 2
#  Non-dangeorus: 9
#      Proportion: 22.22222222222222 %
# Date: 2022-03-12
#  Dangerous: 2
#  Non-dangeorus: 9
#      Proportion: 22.22222222222222 %
# Date: 2022-03-13
#  Dangerous: 2
#  Non-dangeorus: 24
#      Proportion: 8.333333333333334 %
# Date: 2022-03-14
#  Dangerous: 0
#  Non-dangeorus: 19
#      Proportion: 0.0 %
# Date: 2022-03-15
#  Dangerous: 2
#  Non-dangeorus: 11
#      Proportion: 18.181818181818183 %
# Date: 2022-03-16
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-03-17
#  Dangerous: 0
#  Non-dangeorus: 16
#      Proportion: 0.0 %
# Date: 2022-03-18
#  Dangerous: 0
#  Non-dangeorus: 13
#      Proportion: 0.0 %
# Date: 2022-03-19
#  Dangerous: 1
#  Non-dangeorus: 14
#      Proportion: 7.142857142857143 %
# Date: 2022-03-19
#  Dangerous: 1
#  Non-dangeorus: 14
#      Proportion: 7.142857142857143 %
# Date: 2022-03-20
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-03-21
#  Dangerous: 0
#  Non-dangeorus: 16
#      Proportion: 0.0 %
# Date: 2022-03-22
#  Dangerous: 1
#  Non-dangeorus: 12
#      Proportion: 8.333333333333334 %
# Date: 2022-03-23
#  Dangerous: 3
#  Non-dangeorus: 15
#      Proportion: 20.0 %
# Date: 2022-03-24
#  Dangerous: 1
#  Non-dangeorus: 11
#      Proportion: 9.090909090909092 %
# Date: 2022-03-25
#  Dangerous: 0
#  Non-dangeorus: 24
#      Proportion: 0.0 %
# Date: 2022-03-26
#  Dangerous: 1
#  Non-dangeorus: 22
#      Proportion: 4.545454545454546 %
# Date: 2022-03-26
#  Dangerous: 1
#  Non-dangeorus: 22
#      Proportion: 4.545454545454546 %
# Date: 2022-03-27
#  Dangerous: 0
#  Non-dangeorus: 9
#      Proportion: 0.0 %
# Date: 2022-03-28
#  Dangerous: 0
#  Non-dangeorus: 14
#      Proportion: 0.0 %
# Date: 2022-03-29
#  Dangerous: 0
#  Non-dangeorus: 21
#      Proportion: 0.0 %
# Date: 2022-03-30
#  Dangerous: 2
#  Non-dangeorus: 20
#      Proportion: 10.0 %
# Date: 2022-03-31
#  Dangerous: 0
#  Non-dangeorus: 23
#      Proportion: 0.0 %
# Date: 2022-04-01
#  Dangerous: 1
#  Non-dangeorus: 23
#      Proportion: 4.3478260869565215 %
# Date: 2022-04-02
#  Dangerous: 0
#  Non-dangeorus: 27
#      Proportion: 0.0 %
# Date: 2022-04-02
#  Dangerous: 0
#  Non-dangeorus: 27
#      Proportion: 0.0 %
# Date: 2022-04-03
#  Dangerous: 1
#  Non-dangeorus: 12
#      Proportion: 8.333333333333334 %
# Date: 2022-04-04
#  Dangerous: 0
#  Non-dangeorus: 19
#      Proportion: 0.0 %
# Date: 2022-04-05
#  Dangerous: 2
#  Non-dangeorus: 20
#      Proportion: 10.0 %
# Date: 2022-04-06
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-04-07
#  Dangerous: 0
#  Non-dangeorus: 16
#      Proportion: 0.0 %
# Date: 2022-04-08
#  Dangerous: 0
#  Non-dangeorus: 17
#      Proportion: 0.0 %
# Date: 2022-04-09
#  Dangerous: 1
#  Non-dangeorus: 18
#      Proportion: 5.555555555555555 %
# Date: 2022-04-09
#  Dangerous: 1
#  Non-dangeorus: 18
#      Proportion: 5.555555555555555 %
# Date: 2022-04-10
#  Dangerous: 0
#  Non-dangeorus: 26
#      Proportion: 0.0 %
# Date: 2022-04-11
#  Dangerous: 0
#  Non-dangeorus: 16
#      Proportion: 0.0 %
# Date: 2022-04-12
#  Dangerous: 1
#  Non-dangeorus: 6
#      Proportion: 16.666666666666668 %
# Date: 2022-04-13
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-04-14
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-04-15
#  Dangerous: 1
#  Non-dangeorus: 11
#      Proportion: 9.090909090909092 %
# Date: 2022-04-16
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-04-16
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-04-17
#  Dangerous: 0
#  Non-dangeorus: 15
#      Proportion: 0.0 %
# Date: 2022-04-18
#  Dangerous: 1
#  Non-dangeorus: 25
#      Proportion: 4.0 %
# Date: 2022-04-19
#  Dangerous: 1
#  Non-dangeorus: 20
#      Proportion: 5.0 %
# Date: 2022-04-20
#  Dangerous: 0
#  Non-dangeorus: 19
#      Proportion: 0.0 %
# Date: 2022-04-21
#  Dangerous: 0
#  Non-dangeorus: 8
#      Proportion: 0.0 %
# Date: 2022-04-22
#  Dangerous: 0
#  Non-dangeorus: 14
#      Proportion: 0.0 %
# Date: 2022-04-23
#  Dangerous: 1
#  Non-dangeorus: 14
#      Proportion: 7.142857142857143 %
# Date: 2022-04-23
#  Dangerous: 1
#  Non-dangeorus: 14
#      Proportion: 7.142857142857143 %
# Date: 2022-04-24
#  Dangerous: 2
#  Non-dangeorus: 13
#      Proportion: 15.384615384615385 %
# Date: 2022-04-25
#  Dangerous: 1
#  Non-dangeorus: 23
#      Proportion: 4.3478260869565215 %
# Date: 2022-04-26
#  Dangerous: 2
#  Non-dangeorus: 14
#      Proportion: 14.285714285714286 %
# Date: 2022-04-27
#  Dangerous: 0
#  Non-dangeorus: 11
#      Proportion: 0.0 %
# Date: 2022-04-28
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-04-29
#  Dangerous: 0
#  Non-dangeorus: 10
#      Proportion: 0.0 %
# Date: 2022-04-30
#  Dangerous: 1
#  Non-dangeorus: 19
#      Proportion: 5.2631578947368425 %
# Date: 2022-04-30
#  Dangerous: 1
#  Non-dangeorus: 19
#      Proportion: 5.2631578947368425 %
# Date: 2022-05-01
#  Dangerous: 1
#  Non-dangeorus: 25
#      Proportion: 4.0 %
# Date: 2022-05-02
#  Dangerous: 2
#  Non-dangeorus: 19
#      Proportion: 10.526315789473685 %
# Date: 2022-05-03
#  Dangerous: 1
#  Non-dangeorus: 25
#      Proportion: 4.0 %
# Date: 2022-05-04
#  Dangerous: 2
#  Non-dangeorus: 10
#      Proportion: 20.0 %
# Date: 2022-05-05
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-05-06
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-05-07
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-05-07
#  Dangerous: 0
#  Non-dangeorus: 18
#      Proportion: 0.0 %
# Date: 2022-05-08
#  Dangerous: 1
#  Non-dangeorus: 12
#      Proportion: 8.333333333333334 %
# Date: 2022-05-09
#  Dangerous: 0
#  Non-dangeorus: 13
#      Proportion: 0.0 %
# Date: 2022-05-10
#  Dangerous: 1
#  Non-dangeorus: 16
#      Proportion: 6.25 %
# Date: 2022-05-11
#  Dangerous: 2
#  Non-dangeorus: 15
#      Proportion: 13.333333333333334 %
# Date: 2022-05-12
#  Dangerous: 0
#  Non-dangeorus: 11
#      Proportion: 0.0 %
# Date: 2022-05-13
#  Dangerous: 0
#  Non-dangeorus: 12
#      Proportion: 0.0 %
# Date: 2022-05-14
#  Dangerous: 0
#  Non-dangeorus: 17
#      Proportion: 0.0 %
# Date: 2022-05-14
#  Dangerous: 0
#  Non-dangeorus: 17
#      Proportion: 0.0 %
# Date: 2022-05-15
#  Dangerous: 1
#  Non-dangeorus: 13
#      Proportion: 7.6923076923076925 %
# Date: 2022-05-16
#  Dangerous: 1
#  Non-dangeorus: 18
#      Proportion: 5.555555555555555 %
# Date: 2022-05-17
#  Dangerous: 1
#  Non-dangeorus: 7
#      Proportion: 14.285714285714286 %
# Date: 2022-05-18
#  Dangerous: 0
#  Non-dangeorus: 13
#      Proportion: 0.0 %
# Date: 2022-05-19
#  Dangerous: 1
#  Non-dangeorus: 19
#      Proportion: 5.2631578947368425 %
# Date: 2022-05-20
#  Dangerous: 2
#  Non-dangeorus: 18
#      Proportion: 11.11111111111111 %
# Date: 2022-05-21
#  Dangerous: 1
#  Non-dangeorus: 9
#      Proportion: 11.11111111111111 %

# %% [markdown]
# ### Task 3: Data Visualization Part A
#
# - Create a line plot of the number of NEOs per week.
# - Create a histogram of the distribution of NEO sizes.
# - Create a bar plot of the average NEO size per week.
# - Use a library like Seaborn to create more complex visualizations, such as a box plot of the NEO sizes or a heat map of the number of NEOs per week. **Be creative**!

# %%
# Write your code

# %% [markdown]
# ### Task 4: Data Visualization Part B
#
# - Create a pie chart of the proportion of hazardous vs non-hazardous NEOs.
# - Create a scatter plot of the correlation between NEO size and close approach distance.
# - Customize the appearance of your plots (e.g., colors, labels, titles).
# - Create interactive visualizations using a library like Plotly. For example, create an interactive scatter plot where you can hover over each point to see more information about the NEO. **Be creative!**

# %%
# Write your code

# %% [markdown]
# ### Task 5: Interpretation of Results
#
# - Interpret the results of your data visualization in part A and B.
# - What insights can you gain about NEOs from your results? Summarizing your findings.
# - Use your findings to make predictions or recommendations. For example, if you found that larger NEOs are more likely to be potentially hazardous, you could recommend that more resources be allocated to tracking large NEOs. **Be creative!**
# - Identify, understand, and explain one scientific paper, on a clustering or classification method of relevance that could help Task 5. You don't have to implement it, you just need to justify in this notebook why the method in the scientific paper could contribute in analysis or interpretation of the results.

# %%
# Write your code

# %% [markdown]
# ### Task 6: Presentation and Documentation
#
# - Make this project as part of your presentation, **using beamer in LaTeX**.
# - This should include an overview of your work, the results of your data analysis, and the insights you gained from your results.
